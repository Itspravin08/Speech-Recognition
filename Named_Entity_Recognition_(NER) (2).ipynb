# %% [markdown]
# ##***Named Entity Recognition (NER) in Python with Spacy***
#
# **What is a Named Entity?**
# A named entity is basically a real-life object which has proper identification and can be denoted with a proper name. Named Entities can be a place, person, organization, time, object, or geographic entity.
#
# For example, named entities would be Roger Federer, Honda city, Samsung Galaxy S10. Named entities are usually instances of entity instances. For example, Roger Federer is an instance of a Tennis Player/person, Honda City is an instance of a car and Samsung Galaxy S10 is an instance of a Mobile Phone.
#
# **Named Entity Recognition:**
# Named Entity Recognition is the process of NLP which deals with identifying and classifying named entities. The raw and structured text is taken and named entities are classified into persons, organizations, places, money, time, etc. Basically, named entities are identified and segmented into various predefined classes.
#
# NER systems are developed with various linguistic approaches, as well as statistical and machine learning methods. NER has many applications for project or business purposes.

# %% [markdown]
# ###**import spacy**
#
# Spacy is an open-source Natural Language Processing library that can be used for various tasks. It has built-in methods for Named Entity Recognition. Spacy has a fast statistical entity recognition system.
#
#  We can use spacy very easily for NER tasks. Though often we need to train our own data for business-specific needs, the spacy model general performs well for all types of text data.

# %% [markdown]
# ![pasted image 0.png](data:image/png;base64,...)

# %%
import spacy
import spacy.displacy as displacy  #  By using this visualization suite namely displaCy, we can visualize a dependency parser or named entity in a text.

# %% [markdown]
# ### **load spacy model**
#
# English pipeline optimized for CPU. Components: tok2vec, tagger, parser, senter, ner, attribute_ruler, lemmatizer.

# %%
nlp = spacy.load('en_core_web_sm') # en_core_web_sm is a small English pipeline trained on written web text (blogs, news, comments), that includes vocabulary, syntax and entities.

# %% [markdown]
# ###**load data**

# %%
with open("the_audio.txt","r") as file:
  var = file.read()
  print(var)
# Out:
# hello Nancy this is Mike from AT&T Incorporation , Nancy has been using our prepaid connection for a couple of years now , how would you like a postpaid connections that allows you to make free unlimited , I would love that , like any other postpaid connection ,

# %%
sentence = "/content/the_audio.txt"
doc = nlp(var)

# %% [markdown]
# ###**print entities**

# %%
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Nancy 6 11 PERSON
# Mike 20 24 PERSON
# AT&T Incorporation 30 48 ORG
# Nancy 51 56 PERSON
# a couple of years 99 116 DATE

# %%
displacy.render(doc,style="ent",jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">hello
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nancy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  this is
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mike
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AT&amp;T Incorporation
# ...

# %% [markdown]
# ##================================ ***Using nltk NER*** ==================================

# %% [markdown]
# ##***Named Entity Recognition (NER) in Python with nltk***
#
# nltk is a leading python-based library for performing NLP tasks such as preprocessing text data, modelling data, parts of speech tagging, evaluating models and more. It can be widely used across operating systems and is simple in terms of additional configurations. Now, lets install nltk and perform NER on a simple sentence.

# %% [markdown]
# ### **Step One: Import nltk and download necessary packages**

# %%
import nltk
nltk.download('punkt')  # Punkt Sentence Tokenizer
nltk.download('averaged_perceptron_tagger') # The averaged_perceptron_tagger.zip contains the pre-trained English [Part-of-Speech (POS]](https://en.wikipedia.org/wiki/Part_of_speech) tagger in NLTK.
nltk.download('maxent_ne_chunker')  # The maxent_ne_chunker contains two pre-trained English named entity chunkers trained on an ACE corpus
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %% [markdown]
# ###**Step Two: Load Data**

# %%
sentence = "WASHINGTON -- In the wake of a string of abuses by New York police officers in the 1990s, Loretta E. Lynch, the top federal prosecutor in Brooklyn, spoke forcefully about the pain of a broken trust that African-Americans felt and said the responsibility for repairing generations of miscommunication and mistrust fell to law enforcement."

# %% [markdown]
# ### **Step Three: Tokenise, find parts of speech and chunk words**

# %%
for sent in nltk.sent_tokenize(sentence):
  for chunk in nltk.ne_chunk(nltk.pos_tag(nltk.word_tokenize(sent))):
     if hasattr(chunk, 'label'):
        NER = chunk.label(), ' '.join(c[0] for c in chunk)
        print(NER)
# Out:
# ('GPE', 'WASHINGTON')
# ('GPE', 'New York')
# ('PERSON', 'Loretta E. Lynch')
# ('GPE', 'Brooklyn')

# %% [markdown]
# #<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<< **END** >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
